# %% [markdown]
# # Dataset readiness check
# Read-only bounded check of headers, tails and the first 5,000 rows per file. This does not verify full-file integrity or corrected-release provenance.

# %%
from pathlib import Path
exec(compile(Path("check.py").read_text(), str(Path("check.py").resolve()), "exec"), {"__name__": "__main__", "__file__": str(Path("check.py").resolve())})
